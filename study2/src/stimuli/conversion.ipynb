# %%
import pandas as pd

df = pd.read_json("norming-targets.json")
df.T.reset_index(names="target").to_csv("norming-targets-fixed.csv", index=False)

# %%
df = pd.read_json("norming-targets-fixed.json")
df
# Out:
#                 target morality  \
# 0    Abdul Sattar Edhi    moral
# 1         Fe del Mundo    moral
# 2           Tom Catena    moral
# 3     Catherine Hamlin    moral
# 4    Hugh Thompson Jr.    moral
# ..                 ...      ...
# 95   Paolo Macchiarini  immoral
# 96  General Butt Naked  immoral
# 97   Oskar Dirlewanger  immoral
# 98      Eugene de Kock  immoral
# 99     Enriqueta Martí  immoral
#
#                                                 intro  \
# 0   Abdul Sattar Edhi was a Pakistani humanitarian...
# 1   Fe del Mundo was a Filipino pediatrician and t...
# 2   Tom Catena is an American physician and Cathol...
# 3   Catherine Hamlin was an Australian obstetricia...
# 4   Hugh Thompson Jr. was a U.S. Army helicopter p...
# ..                                                ...
# 95  Paolo Macchiarini is an Italian thoracic surge...
# 96  Joshua Milton Blahyi, known as General Butt Na...
# 97  Oskar Dirlewanger was the commander of the SS-...
# ...
